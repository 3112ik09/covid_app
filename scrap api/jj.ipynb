# %%
import pandas as pd

# %%
df.head()
# Out:
#   "State/UTs","Total Vaccination Doses","Dose1","Dose2","Vaccination Doses Day Before",
# 0  'Andaman and Nicobar','4,36,63193','2,88,52329...
# 1  'Andhra Pradesh','3,91,56,4751,60,402','2,63,3...
# 2  'Arunachal Pradesh','11,37,0642,442','7,51,290...
# 3  'Assam','2,34,27,60275,262','1,81,50,84841,920...
# 4  'Bihar','5,33,80,3642,37,794','4,29,44,2351,59...

# %%
df = pd.read_csv("data0.txt",delimiter=',')
df.to_csv('Demo1.csv')

# %%
df = pd.read_csv("vaccine.csv")
df.head()
df.drop(0)
# Out:
#                                    State/UTs Total Vaccination Doses  \
# 0                        Andaman and Nicobar           4,38,5001,869
# 1                             Andhra Pradesh     3,97,36,4895,80,014
# 2                          Arunachal Pradesh         11,48,68611,622
# 3                                      Assam     2,36,34,7422,07,140
# 4                                      Bihar     5,38,14,7014,34,337
# 5                                 Chandigarh          13,31,7196,725
# 6                               Chhattisgarh     1,80,21,6781,22,279
# 7   Dadra and Nagar Haveli and Daman and Diu           9,05,5207,091
# 8                                      Delhi     1,73,77,0512,06,007
# 9                                        Goa         18,88,33616,453
# 10                                   Gujarat     6,00,58,7915,26,277
# 11                                   Haryana     2,24,23,2441,23,219
# 12                          Himachal Pradesh         82,79,22951,974
# ...

# %%
df2 = pd.read_csv("corona.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0       State/UTs      Total Cases         Active  \
# 0           0     Maharashtra        65,44,325       41,39632
# 1           1          Kerala  46,41,58711,699  1,57,7336,122
# 2           2       Karnataka     29,73,899504      12,833409
# 3           3      Tamil Nadu   26,58,9231,657       17,26124
# 4           4  Andhra Pradesh     20,47,459618      12,482566
#
#         Discharged      Deaths Active Ratio Discharge Ratio Death Ratio  \
# 0        63,64,027  1,38,90232        0.63%          97.24%       2.12%
# 1  44,59,19317,763    24,66158        3.40%          96.07%       0.53%
# 2     29,23,320893    37,74620        0.43%          98.30%       1.27%
# 3   26,06,1531,662    35,50919        0.65%          98.02%       1.34%
# 4   20,20,8351,178     14,1426        0.61%          98.70%       0.69%
#
#    Unnamed: 8
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
j = df.index[df["State/UTs"]=="Kerala"]
df1 =  df.iloc[j]

# %%
df2
# Out:
# {'Unnamed: 0': {16: 16},
#  'State/UTs': {16: 'Kerala'},
#  'Total Vaccination Doses': {16: '3,51,74,86362,890'},
#  'Dose1': {16: '2,45,44,94923,316'},
#  'Dose2': {16: '1,06,29,91439,574'},
#  'Vaccination Doses Day Before': {16: '3,51,11,973'},
#  'Unnamed: 5': {16: nan}}

# %%
df2.to_dict('index')
# Out:
# {16: {'Unnamed: 0': 16,
#   'State/UTs': 'Kerala',
#   'Total Vaccination Doses': '3,51,74,86362,890',
#   'Dose1': '2,45,44,94923,316',
#   'Dose2': '1,06,29,91439,574',
#   'Vaccination Doses Day Before': '3,51,11,973',
#   'Unnamed: 5': nan}}

# %%
# Out:
# {'Unnamed: 0': {16: 16},
#  'State/UTs': {16: 'Kerala'},
#  'Total Vaccination Doses': {16: '3,51,74,86362,890'},
#  'Dose1': {16: '2,45,44,94923,316'},
#  'Dose2': {16: '1,06,29,91439,574'},
#  'Vaccination Doses Day Before': {16: '3,51,11,973'},
#  'Unnamed: 5': {16: nan}}

# %%
|
